# %% [markdown]
# # Functions to handle nested lists & dictionaries in dataframes

# %% [markdown]
# changelog:
# - change 'dataframe' parameters to 'df'
# - change return statements (remove parens)
# - columns_to_expand: change row index 1 to 0 (0-based python indexing), make list comprehension
# - unnest_column: modify df & assign back to df instead of new df with more complex name (saves from creating variables just to change and not use them)
# - expand_columns:
#     - remove \_i\_ variables to save space (instead of making new variables for every loop)
#     - change loop index to be col instead of i (better readability)
#     - remove code that casts each label as a string, since that is already the default for the code
#     - change vars for column name expansion to be more readable
#     - add 'remove' flag for removing source column (would be redundant info)

# %% [markdown]
# ### Flatten nested DataFrame

# %%
def is_nested(col):
    return any([True for x in col if type(x) in (dict, list)])

# %%
def expand_series(series):
    # Ensure variable is of proper type
    try:
        assert isinstance(series, pd.Series)
    except AssertionError:
        raise ValueError(f'series argument must be of type pd.Series, not {type(series)}')
        
    ## Expand column
    col_expand = series.apply(pd.Series).dropna(axis=1, how='all')
    col_name = series.name

    ## Rename expanded columns to clarify source
    #add source column name prefix to each new column to identify source
    col_expand_names = [f'{col_name}_{nested_col}' for nested_col in col_expand.columns]
    #rename columns
    col_expand.columns = col_expand_names

    return col_expand

# %%
def flatten_nested_df(df):
    """
    Takes in a DataFrame and flattens any nested columns.
    
    Params:
    - df: pd.DataFrame
    """
    # If the df is empty, then we want to return
    if df.empty:
        return df
    # If the df is a Series, convert to DataFrame
    if isinstance(df, pd.Series):
        df = pd.DataFrame(df)
    # If there's only one column & it's not nested, return it
    if df.shape[1] == 1:
        if not is_nested(df.iloc[:,0]):
            return df
    
    # Slice the first column off of the DataFrame
    first_col, df = df.iloc[:, 0], df.iloc[:, 1:]
    
    # If the first column is nested, unnest it
    if is_nested(first_col):
        first_col = expand_series(first_col)
    
    # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
    return flatten_nested_df(first_col).join(flatten_nested_df(df))

# %%
# %%timeit
df = pd.DataFrame(output['hits']['hits'])
flatten_nested_df(df).head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-48dc02ad6711> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "df = pd.DataFrame(output['hits']['hits'])\nflatten_nested_df(df).head()\n")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1171                     break
#    1172
# -> 1173         all_runs = timer.repeat(repeat, number)
#    1174         best = min(all_runs) / number
#    1175         worst = max(all_runs) / number
#
# ~/opt/anaconda3/lib/python3.8/timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
# ---> 27     return flatten_nested_df(first_col).join(flatten_nested_df(df))
#
# <ipython-input-9-ebe7bc3d8276> in flatten_nested_df(df)
#      22     # If the first column is nested, unnest it
#      23     if is_nested(first_col):
# ---> 24         first_col = expand_series(first_col)
#      25
#      26     # Want to flatten the first column again (in case nested nested) and combine with the rest of the flattened df
#
# <ipython-input-8-1852436db349> in expand_series(series)
#       7
#       8     ## Expand column
# ----> 9     col_expand = series.apply(pd.Series).dropna(axis=1, how='all')
#      10     col_name = series.name
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     341                 if not is_list_like(data):
#     342                     data = [data]
# --> 343                 index = ibase.default_index(len(data))
#     344             elif is_list_like(data):
#     345
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in default_index(n)
#    5948     from pandas.core.indexes.range import RangeIndex
#    5949
# -> 5950     return RangeIndex(0, n, name=None)
#    5951
#    5952
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in __new__(cls, start, stop, step, dtype, copy, name)
#      96
#      97         # validate the arguments
# ---> 98         if com.all_none(start, stop, step):
#      99             raise TypeError("RangeIndex(...) must be called with integers")
#     100
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/common.py in all_none(*args)
#     172     Returns a boolean indicating if all arguments are None.
#     173     """
# --> 174     return all(arg is None for arg in args)
#     175
#     176
#
# KeyboardInterrupt:

# %%
pd.DataFrame([flatten(result) for result in output['hits']['hits']])
# Out:
#                  conceptdoi conceptrecid                           created  \
# 0    10.5281/zenodo.3662112      3662112  2020-02-11T09:00:48.461959+00:00
# 1    10.5281/zenodo.3530883      3530883  2019-11-06T21:34:30.631777+00:00
# 2    10.5281/zenodo.4738769      4738769  2021-05-05T10:21:43.604973+00:00
# 3                       NaN      4768051  2021-05-17T17:53:16.165204+00:00
# 4                       NaN      3461067  2019-09-26T00:12:55.671236+00:00
# ..                      ...          ...                               ...
# 995  10.5281/zenodo.3885379      3885379  2020-06-08T13:45:13.634996+00:00
# 996  10.5281/zenodo.4330625      4330625  2020-12-17T00:12:53.596641+00:00
# 997  10.5281/zenodo.3982839      3982839  2020-08-13T16:31:08.841046+00:00
# 998  10.5281/zenodo.4738546      4738546  2021-05-05T08:27:32.575962+00:00
# 999                     NaN      3764648  2020-04-24T08:46:35.633521+00:00
#
#                                 doi                        files_0_bucket  \
# 0            10.5281/zenodo.3662113  54dc6794-9135-4217-af9e-cc1649960b90
# 1            10.5281/zenodo.3530884  0b2a69fa-3fcf-46d6-b8e5-fbffe4118952
# 2            10.5281/zenodo.4738770  fdefeabc-7897-4130-9628-438795c877c2
# 3        10.1007/s10994-021-05968-x  a43e8b77-a43a-488c-8e02-489f02047271
# 4        10.1007/s10994-019-05800-7  9503c5c7-366f-42f6-8400-136e06048bf5
# ..                              ...                                   ...
# 995          10.5281/zenodo.3885380  7f3afc61-6fd0-490d-b33c-4ebb9f4114f3
# 996          10.5281/zenodo.4330626  f153353f-3eb6-42ae-8c39-499472ccdf18
# 997          10.5281/zenodo.3982840  0f00582c-eeff-4529-b26a-e57d03f17487
# 998          10.5281/zenodo.4738547  715bcc1b-7643-4f77-bd70-d1af56c99f92
# 999  10.1109/SYNASC49474.2019.00042                                   NaN
#
#                          files_0_checksum  \
# 0    md5:c4da02730a59a3dea2f1cbad807ac198
# 1    md5:643878148673ee42bd3dba97317de02a
# 2    md5:0c8ea118118b0300a150b7f54ffc56e8
# 3    md5:82cb35e198d55ae12aef1e51f1aefb10
# 4    md5:1154a531d98a264cf0be1c2ff5c6df58
# ..                                    ...
# 995  md5:eac2b256689593bb3e64b00086ac3180
# 996  md5:257084366693d11c1ac4095d7dd9d06b
# 997  md5:70be06a4f15f50744b9a8ab1d0c87b93
# 998  md5:fe0e423ffde47ff3c9bc4132622bfd72
# 999                                   NaN
#
#                                            files_0_key  \
# 0                              opium-sh/prl-v0.1.0.zip
# 1           kratzert/ealstm_regional_modeling-v1.0.zip
# 2                   kratzert/multiple_forcing-v1.0.zip
# 3    Škrlj2021_Article_AutoBOTEvolvingNeuro-symbol...
# 4                                   mlsvm-1.1.0.tar.gz
# ..                                                 ...
# 995                  Report_Ravi_Charan Nudurupati.pdf
# 996                                      czi_2020.pptx
# 997    01 Paper 01072023 IJCSIS Camera Ready pp1-5.pdf
# 998  STOCK_MARKET_PREDICTION_USING_ANFIS_MACHINE_LE...
# 999                                                NaN
#
#                                     files_0_links_self  files_0_size  \
# 0    https://zenodo.org/api/files/54dc6794-9135-421...       54220.0
# 1    https://zenodo.org/api/files/0b2a69fa-3fcf-46d...    13877577.0
# 2    https://zenodo.org/api/files/fdefeabc-7897-413...      133317.0
# 3    https://zenodo.org/api/files/a43e8b77-a43a-488...     3000278.0
# 4    https://zenodo.org/api/files/9503c5c7-366f-42f...    15351705.0
# ..                                                 ...           ...
# 995  https://zenodo.org/api/files/7f3afc61-6fd0-490...     1222283.0
# 996  https://zenodo.org/api/files/f153353f-3eb6-42a...    89373190.0
# 997  https://zenodo.org/api/files/0f00582c-eeff-452...      709009.0
# 998  https://zenodo.org/api/files/715bcc1b-7643-4f7...      426325.0
# 999                                                NaN           NaN
#
#     files_0_type  ...  files_206_key files_206_links_self files_206_size  \
# 0            zip  ...            NaN                  NaN            NaN
# 1            zip  ...            NaN                  NaN            NaN
# 2            zip  ...            NaN                  NaN            NaN
# 3            pdf  ...            NaN                  NaN            NaN
# 4             gz  ...            NaN                  NaN            NaN
# ..           ...  ...            ...                  ...            ...
# 995          pdf  ...            NaN                  NaN            NaN
# 996         pptx  ...            NaN                  NaN            NaN
# 997          pdf  ...            NaN                  NaN            NaN
# 998          pdf  ...            NaN                  NaN            NaN
# 999          NaN  ...            NaN                  NaN            NaN
#
#     files_206_type files_207_bucket files_207_checksum files_207_key  \
# 0              NaN              NaN                NaN           NaN
# 1              NaN              NaN                NaN           NaN
# 2              NaN              NaN                NaN           NaN
# 3              NaN              NaN                NaN           NaN
# 4              NaN              NaN                NaN           NaN
# ..             ...              ...                ...           ...
# 995            NaN              NaN                NaN           NaN
# 996            NaN              NaN                NaN           NaN
# 997            NaN              NaN                NaN           NaN
# 998            NaN              NaN                NaN           NaN
# 999            NaN              NaN                NaN           NaN
#
#     files_207_links_self files_207_size files_207_type
# 0                    NaN            NaN            NaN
# 1                    NaN            NaN            NaN
# 2                    NaN            NaN            NaN
# 3                    NaN            NaN            NaN
# 4                    NaN            NaN            NaN
# ..                   ...            ...            ...
# 995                  NaN            NaN            NaN
# 996                  NaN            NaN            NaN
# 997                  NaN            NaN            NaN
# 998                  NaN            NaN            NaN
# 999                  NaN            NaN            NaN
#
# [1000 rows x 1769 columns]

# %% [markdown]
# ### Example using Zenodo API output

# %%
#import libraries
import os
import requests
import pandas as pd
import pickle
import pprint as pp
from flatten_json import flatten

# %%
#load credentials
with open('credentials.pkl', 'rb') as credentials:
        ZENODO_TOKEN = pickle.load(credentials)['ZENODO_TOKEN']

# %%
#Specify search term
SEARCH_TERM = 'machine learning'

#Specify parameters
PARAMS = {'q': SEARCH_TERM,
         'access_token': ZENODO_TOKEN,
         'page': 1,
         'size': 1000}

#Search
response = requests.get('https://zenodo.org/api/records', 
                        params = PARAMS)

# %%
#Put output into json format
output = response.json()

# %%
#View output
pp.pprint(output)
# Out:
# {'aggregations': {'access_right': {'buckets': [{'doc_count': 28, 'key': 'open'},
#                                                {'doc_count': 3,
#                                                 'key': 'closed'}],
#                                    'doc_count_error_upper_bound': 0,
#                                    'sum_other_doc_count': 0},
#                   'file_type': {'buckets': [{'doc_count': 6, 'key': 'txt'},
#                                             {'doc_count': 5, 'key': 'csv'},
#                                             {'doc_count': 5, 'key': 'pdf'},
#                                             {'doc_count': 4, 'key': 'html'},
#                                             {'doc_count': 4, 'key': 'xlsx'},
#                                             {'doc_count': 3, 'key': 'zip'},
#                                             {'doc_count': 2, 'key': 'gz'},
#                                             {'doc_count': 2, 'key': 'nex'},
#                                             {'doc_count': 2, 'key': 'xls'},
#                                             {'doc_count': 1, 'key': 'docx'}],
#                                 'doc_count_error_upper_bound': 0,
#                                 'sum_other_doc_count': 6},
#                   'keywords': {'buckets': [{'doc_count': 8,
#                                             'key': 'Biodiversity'},
#                                            {'doc_count': 8, 'key': 'Taxonomy'},
#                                            {'doc_count': 6, 'key': 'Animalia'},
#                                            {'doc_count': 6,
#                                             'key': 'Tamias striatus'},
#                                            {'doc_count': 4, 'key': 'Tamias'},
#                                            {'doc_count': 3,
#                                             'key': 'Arthropoda'},
#                                            {'doc_count': 3,
#                                             'key': 'Tamias alpinus'},
#                                            {'doc_count': 3,
#                                             'key': 'Tamias speciosus'},
#                                            {'doc_count': 3, 'key': 'chipmunks'},
#                                            {'doc_count': 2,
#                                             'key': 'Glucocorticoids'}],
#                                'doc_count_error_upper_bound': 0,
#                                'sum_other_doc_count': 143},
#                   'type': {'buckets': [{'doc_count': 18,
#                                         'key': 'dataset',
#                                         'subtype': {'buckets': [],
#                                                     'doc_count_error_upper_bound': 0,
#                                                     'sum_other_doc_count': 0}},
#                                        {'doc_count': 10,
#                                         'key': 'publication',
#                                         'subtype': {'buckets': [{'doc_count': 6,
#                                                                  'key': 'article'},
#                                                                 {'doc_count': 4,
#                                                                  'key': 'taxonomictreatment'}],
#                                                     'doc_count_error_upper_bound': 0,
#                                                     'sum_other_doc_count': 0}},
#                                        {'doc_count': 2,
#                                         'key': 'software',
#                                         'subtype': {'buckets': [],
#                                                     'doc_count_error_upper_bound': 0,
#                                                     'sum_other_doc_count': 0}},
#                                        {'doc_count': 1,
#                                         'key': 'other',
#                                         'subtype': {'buckets': [],
#                                                     'doc_count_error_upper_bound': 0,
#                                                     'sum_other_doc_count': 0}}],
#                            'doc_count_error_upper_bound': 0,
#                            'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'conceptrecid': '4966916',
#                     'created': '2021-06-16T14:25:57.408732+00:00',
#                     'doi': '10.5061/dryad.c3sg55p',
#                     'files': [{'bucket': '8a26640e-153c-43fb-b97c-5833a35dadbb',
#                                'checksum': 'md5:30f66705913a2690132e4f23274cc4dd',
#                                'key': 'comparative_trees.tar',
#                                'links': {'self': 'https://zenodo.org/api/files/8a26640e-153c-43fb-b97c-5833a35dadbb/comparative_trees.tar'},
#                                'size': 228352,
#                                'type': 'tar'},
#                               {'bucket': '8a26640e-153c-43fb-b97c-5833a35dadbb',
#                                'checksum': 'md5:a074102d253a70c878c6f78f741783fe',
#                                'key': 'H_cucullatum_alignments_trees.tar',
#                                'links': {'self': 'https://zenodo.org/api/files/8a26640e-153c-43fb-b97c-5833a35dadbb/H_cucullatum_alignments_trees.tar'},
#                                'size': 475136,
#                                'type': 'tar'},
#                               {'bucket': '8a26640e-153c-43fb-b97c-5833a35dadbb',
#                                'checksum': 'md5:dfee3740f29443fc1b83e1c2f60ae344',
#                                'key': 'R_eutamii_alignments_trees.tar',
#                                'links': {'self': 'https://zenodo.org/api/files/8a26640e-153c-43fb-b97c-5833a35dadbb/R_eutamii_alignments_trees.tar'},
#                                'size': 270848,
#                                'type': 'tar'},
#                               {'bucket': '8a26640e-153c-43fb-b97c-5833a35dadbb',
#                                'checksum': 'md5:3ac65cb2a57089a07cf8c9df38f42c00',
#                                'key': 'Tamias_host_alignments_trees.tar',
#                                'links': {'self': 'https://zenodo.org/api/files/8a26640e-153c-43fb-b97c-5833a35dadbb/Tamias_host_alignments_trees.tar'},
#                                'size': 184832,
#                                'type': 'tar'}],
#                     'id': 4966917,
#                     'links': {'badge': 'https://zenodo.org/badge/doi/10.5061/dryad.c3sg55p.svg',
#                               'bucket': 'https://zenodo.org/api/files/8a26640e-153c-43fb-b97c-5833a35dadbb',
#                               'doi': 'https://doi.org/10.5061/dryad.c3sg55p',
#                               'html': 'https://zenodo.org/record/4966917',
#                               'latest': 'https://zenodo.org/api/records/4966917',
#                               'latest_html': 'https://zenodo.org/record/4966917',
#                               'self': 'https://zenodo.org/api/records/4966917'},
#                     'metadata': {'access_right': 'open',
#                                  'access_right_category': 'success',
#                                  'communities': [{'id': 'dryad'}],
#                                  'creators': [{'name': 'Bell, Kayce C.'},
#                                               {'name': 'Demboski, John R.'},
#                                               {'name': 'Cook, Joseph A.'}],
#                                  'description': 'Parasitism is a common '
#                                                 'symbiotic interaction across '
#                                                 'diverse natural systems. '
#                                                 'Using a comparative '
#                                                 'evolutionary approach, we '
#                                                 'investigated the '
#                                                 'contributions of both host '
#                                                 'phylogeny and abiotic factors '
#                                                 'towards diversification of '
#                                                 'phylogenetically independent '
#                                                 'endoparasites that inhabit '
#                                                 'essentially the same physical '
#                                                 'space. We tested for '
#                                                 'host-parasite and '
#                                                 'parasite-parasite '
#                                                 'phylogenetic concordance in '
#                                                 'western North American '
#                                                 'chipmunks (Rodentia: '
#                                                 'Sciuridae) and two distantly '
#                                                 'related species of pinworms '
#                                                 '(Nematoda: Oxyurida). Deep '
#                                                 'structure in molecular '
#                                                 'phylogenies revealed signals '
#                                                 'of host-associated divergence '
#                                                 'in both parasite species, '
#                                                 'while shallower '
#                                                 'phylogeographic structure '
#                                                 'varied between the two '
#                                                 'parasites. This suggests that '
#                                                 'although these parasites '
#                                                 'experienced similar '
#                                                 'landscapes and cyclic climate '
#                                                 'processes, temporally '
#                                                 'distinctive diversification '
#                                                 'events were associated with '
#                                                 'differences in the initiation '
#                                                 'of their association with '
#                                                 'host lineages. When climate '
#                                                 'cycles initiate '
#                                                 'diversification, partially '
#                                                 'congruent, but asynchronous '
#                                                 'host-associated parasite '
#                                                 'phylogenies may emerge.',
#                                  'doi': '10.5061/dryad.c3sg55p',
#                                  'keywords': ['pinworm',
#                                               'Rauschtineria eutamii',
#                                               'Evolution: host/parasite',
#                                               'chipmunk',
#                                               'Heteroxynema cucullatum',
#                                               'host-parasite codiversification',
#                                               'comparative phylogeography',
#                                               'Tamias spp.'],
#                                  'license': {'id': 'CC0-1.0'},
#                                  'locations': [{'place': 'western North '
#                                                          'America'}],
#                                  'notes': '<div '
#                                           'class="o-metadata__file-usage-entry">Heteroxynema '
#                                           'cucullatum DNA sequence alignments '
#                                           'and phylogenies<div '
#                                           'class="o-metadata__file-description">H_cucullatum_3loci_concatenated_MrBayes.tre: '
#                                           'MrBayes tree of Heteroxynema '
#                                           'cucullatum concatenated loci COI, '
#                                           'ITS+, 28S\n'
#                                           'H_cucullatum_3loci_starbeast.tre: '
#                                           'Starbeast species tree of '
#                                           'Heteroxynema cucullatum loci COI, '
#                                           'ITS+, 28S\n'
#                                           'H_cucullatum_COI_quadrivittatus_hosts_MrBayes.tre: '
#                                           'MrBayes gene tree of COI for '
#                                           'Heteroxynema cucullatum individuals '
#                                           'that corespond to quadrivittatus '
#                                           'group hosts (used in tanglegram)\n'
#                                           'H_cucullatum_COI_T_minimus_hosts_MrBayes.tre: '
#                                           'MrBayes gene tree of COI for '
#                                           'Heteroxynema cucullatum individuals '
#                                           'that corespond to Tamias minimus '
#                                           'hosts (used in tanglegram)\n'
#                                           'Heteroxynema_cucullatum_28S_MrBayes.tre: '
#                                           'MrBayes gene tree of Heteroxynema '
#                                           'cucullatum 28S\n'
#                                           'Heteroxynema_cucullatum_28S_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Heteroxynema cucullatum 28S\n'
#                                           'Heteroxynema_cucullatum_COI_MrBayes.tre: '
#                                           'MrBayes gene tree of Heteroxynema '
#                                           'cucullatum COI\n'
#                                           'Heteroxynema_cucullatum_COI_RAxML.tre: '
#                                           'RAxML gene tree of Heteroxynema '
#                                           'cucullatum COI\n'
#                                           'Heteroxynema_cucullatum_COI_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Heteroxynema cucullatum COI\n'
#                                           'Heteroxynema_cucullatum_ITS_MrBayes.tre: '
#                                           'MrBayes gene tree of Heteroxynema '
#                                           'cucullatum ITS+\n'
#                                           'Heteroxynema_cucullatum_ITS_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Heteroxynema cucullatum '
#                                           'ITS+</div><div '
#                                           'class="o-metadata__file-name">H_cucullatum_alignments_trees.tar<br></div></div><div '
#                                           'class="o-metadata__file-usage-entry">Rauschtineria '
#                                           'eutamii DNA sequence alignments and '
#                                           'phylogenies<div '
#                                           'class="o-metadata__file-description">R_eutamii_4loci_concatenated_MrBayes.tre: '
#                                           'MrBayes tree of Rauschtineria '
#                                           'eutamii concatenated loci COI, 12S, '
#                                           '18S, 28S\n'
#                                           'R_eutamii_4loci_starbeast.tre: '
#                                           'Starbeast species tree of '
#                                           'Rauschtineria eutamii loci COI, '
#                                           '12S, 18S, 28S\n'
#                                           'R_eutamii_COI_minimus_hosts_MrBayes.tre: '
#                                           'MrBayes gene tree of COI for '
#                                           'Rauschtineria eutamii individuals '
#                                           'that corespond to Tamias minimus '
#                                           'hosts (used in tanglegram)\n'
#                                           'R_eutamii_COI_quadrivittatus_hosts_MrBayes.tre: '
#                                           'MrBayes gene tree of COI for '
#                                           'Rauschtineria eutamii individuals '
#                                           'that corespond to quadrivittatus '
#                                           'group hosts (used in tanglegram)\n'
#                                           'Rauschtineria_eutamii_12S_MrBayes.tre: '
#                                           'MrBayes gene tree of Rauschtineria '
#                                           'eutamii 12S\n'
#                                           'Rauschtineria_eutamii_12S_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Rauschtineria eutamii 12S\n'
#                                           'Rauschtineria_eutamii_18S_MrBayes.tre: '
#                                           'MrBayes gene tree of Rauschtineria '
#                                           'eutamii 18S\n'
#                                           'Rauschtineria_eutamii_18S_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Rauschtineria eutamii 18S\n'
#                                           'Rauschtineria_eutamii_28S_MrBayes.tre: '
#                                           'MrBayes gene tree of Rauschtineria '
#                                           'eutamii 28S\n'
#                                           'Rauschtineria_eutamii_28S_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Rauschtineria eutamii 28S\n'
#                                           'Rauschtineria_eutamii_COI_MrBayes.tre: '
#                                           'MrBayes gene tree of Rauschtineria '
#                                           'eutamii COI\n'
#                                           'Rauschtineria_eutamii_COI_RAxML.tre: '
#                                           'RAxML gene tree of Rauschtineria '
#                                           'eutamii COI\n'
#                                           'Rauschtineria_eutamii_COI_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'Rauschtineria eutamii COI</div><div '
#                                           'class="o-metadata__file-name">R_eutamii_alignments_trees.tar<br></div></div><div '
#                                           'class="o-metadata__file-usage-entry">Tamias '
#                                           'DNA sequence alignments and gene '
#                                           'trees<div '
#                                           'class="o-metadata__file-description">T_minimus_cytb_hosts_of_H_cucullatum_MrBayes.tre: '
#                                           'MrBayes gene tree of cytochrome b '
#                                           'for Tamias minimus individuals that '
#                                           'correspond to Heteroxynema '
#                                           'cucullatum individuals (used in '
#                                           'tanglegram)\n'
#                                           'T_minimus_cytb_hosts_of_H_cucullatum_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'cytochrome b for Tamias minimus '
#                                           'individuals that correspond to '
#                                           'Heteroxynema cucullatum '
#                                           'individuals\n'
#                                           'T_minimus_cytb_hosts_of_R_eutamii_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'cytochrome b for Tamias minimus '
#                                           'individuals that correspond to '
#                                           'Rauschtineria eutamii individuals\n'
#                                           'T_minimus_cytb_hosts_of_R_eutamii_MrBayes.tre: '
#                                           'MrBayes gene tree of cytochrome b '
#                                           'for Tamias minimus individuals that '
#                                           'correspond to Rauschtineria eutamii '
#                                           'individuals (used in tanglegram)\n'
#                                           'quadrivittatus_cytb_hosts_of_H_cucullatum_MrBayes.tre: '
#                                           'MrBayes gene tree of cytochrome b '
#                                           'for quadrivittatus group '
#                                           'individuals that correspond to '
#                                           'Heteroxynema cucullatum individuals '
#                                           '(used in tanglegram)\n'
#                                           'quadrivittatus_cytb_hosts_of_H_cucullatum_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'cytochrome b for quadrivittatus '
#                                           'group individuals that correspond '
#                                           'to Heteroxynema cucullatum '
#                                           'individuals\n'
#                                           'quadrivittatus_cytb_hosts_of_R_eutamii_MrBayes.tre: '
#                                           'MrBayes gene tree of cytochrome b '
#                                           'for quadrivittatus group '
#                                           'individuals that correspond to '
#                                           'Rauschtineria eutamii individuals '
#                                           '(used in tanglegram)\n'
#                                           'quadrivittatus_cytb_hosts_of_R_eutamii_alignment.nex: '
#                                           'DNA sequence alignment of '
#                                           'cytochrome b for quadrivittatus '
#                                           'group individuals that correspond '
#                                           'to Rauschtineria eutamii '
#                                           'individuals</div><div '
#                                           'class="o-metadata__file-name">Tamias_host_alignments_trees.tar<br></div></div><div '
#                                           'class="o-metadata__file-usage-entry">Pinworm '
#                                           '&amp; host BUCKy trees and pinworm '
#                                           'COI BEAST tree<div '
#                                           'class="o-metadata__file-description">H_cucullatum_COI_quadrivittatus_cytb_BUCKy.tre: '
#                                           'BUCKy tree with concordance values '
#                                           'for H. cucullatum COI MrBayes trees '
#                                           'and quadrivittatus group cytb '
#                                           'MrBayes trees\n'
#                                           'H_cucullatum_R_eutamii_COI_BUCKy.tre: '
#                                           'BUCKy tree with concordance values '
#                                           'for H. cucullatum and R. eutamii '
#                                           'COI MrBayes trees\n'
#                                           'H_cucullatum_and_R_eutamii_COI_beast_rate_estimates_only.tre: '
#                                           'BEAST tree of COI sequences for H. '
#                                           'cucullatum and R. eutamii, used '
#                                           'only to estimate relative rates\n'
#                                           'H_cucullatum_COI_T_minimus_cytb_BUCKy.tre: '
#                                           'BUCKy tree with concordance values '
#                                           'for H. cucullatum COI MrBayes trees '
#                                           'and T. minimus cytb MrBayes trees\n'
#                                           'R_eutamii_COI_T_minimus_cytb_BUCKy.tre: '
#                                           'BUCKy tree with concordance values '
#                                           'for R. eutamii COI MrBayes trees '
#                                           'and T. minimus cytb MrBayes trees\n'
#                                           'R_eutamii_COI_quadrivittatus_cytb_BUCKy.tre: '
#                                           'BUCKy tree with concordance values '
#                                           'for R. eutamii COI MrBayes trees '
#                                           'and quadrivittatus group cytb '
#                                           'MrBayes trees</div><div '
#                                           'class="o-metadata__file-name">comparative_trees.tar<br></div></div><p>Funding '
#                                           'provided by: National Science '
#                                           'Foundation<br>Award Number: '
#                                           'DEB-0716200, 0956129, 1258010, '
#                                           '1311076</p>',
#                                  'publication_date': '2018-02-26',
#                                  'related_identifiers': [{'identifier': '10.1086/698300',
#                                                           'relation': 'cites',
#                                                           'scheme': 'doi'}],
#                                  'relations': {'version': [{'count': 1,
#                                                             'index': 0,
#                                                             'is_last': True,
#                                                             'last_child': {'pid_type': 'recid',
#                                                                            'pid_value': '4966917'},
#                                                             'parent': {'pid_type': 'recid',
#                                                                        'pid_value': '4966916'}}]},
#                                  'resource_type': {'title': 'Dataset',
#                                                    'type': 'dataset'},
#                                  'title': 'Data from: Sympatric parasites have '
#                                           'similar host-associated, but '
#                                           'asynchronous, patterns of '
#                                           'diversification'},
#                     'owners': [90070],
#                     'revision': 2,
#                     'stats': {'downloads': 0.0,
#                               'unique_downloads': 0.0,
#                               'unique_views': 0.0,
#                               'version_downloads': 0.0,
#                               'version_unique_downloads': 0.0,
#                               'version_unique_views': 0.0,
#                               'version_views': 0.0,
#                               'version_volume': 0.0,
#                               'views': 0.0,
#                               'volume': 0.0},
#                     'updated': '2021-06-17T01:48:21.825621+00:00'},
#                    {'conceptrecid': '4936920',
#                     'created': '2021-06-12T14:37:37.488821+00:00',
#                     'doi': '10.5061/dryad.pn371m9',
#                     'files': [{'bucket': 'fc2f8285-d275-42e0-94e7-00f4dbf3c9a3',
#                                'checksum': 'md5:c9083c5bd0583be6b6998f8630010a03',
#                                'key': 'Data_Emmering et al. JAB01946.xlsx',
#                                'links': {'self': 'https://zenodo.org/api/files/fc2f8285-d275-42e0-94e7-00f4dbf3c9a3/Data_Emmering%20et%20al.%20JAB01946.xlsx'},
#                                'size': 228624,
#                                'type': 'xlsx'}],
#                     'id': 4936921,
#                     'links': {'badge': 'https://zenodo.org/badge/doi/10.5061/dryad.pn371m9.svg',
#                               'bucket': 'https://zenodo.org/api/files/fc2f8285-d275-42e0-94e7-00f4dbf3c9a3',
#                               'doi': 'https://doi.org/10.5061/dryad.pn371m9',
#                               'html': 'https://zenodo.org/record/4936921',
#                               'latest': 'https://zenodo.org/api/records/4936921',
#                               'latest_html': 'https://zenodo.org/record/4936921',
#                               'self': 'https://zenodo.org/api/records/4936921'},
#                     'metadata': {'access_right': 'open',
#                                  'access_right_category': 'success',
#                                  'communities': [{'id': 'dryad'}],
#                                  'creators': [{'affiliation': 'Texas Tech '
#                                                               'University',
#                                                'name': 'Emmering, Quinn C.'},
#                                               {'affiliation': 'University of '
#                                                               'Illinois at '
#                                                               'Urbana '
#                                                               'Champaign',
#                                                'name': 'Kelly, Janice K.'},
#                                               {'affiliation': 'Cary Institute '
#                                                               'of Ecosystem '
#                                                               'Studies',
#                                                'name': 'Ostfeld, Richard S.'},
#                                               {'affiliation': 'Texas Tech '
#                                                               'University',
#                                                'name': 'Schmidt, Kenneth A.'}],
#                                  'description': 'Breeding nest site selection '
#                                                 'is often the first defense '
#                                                 'against nest predation risk. '
#                                                 'To be effective, this '
#                                                 'mechanism requires '
#                                                 'site-specific spatial '
#                                                 'heterogeneity in predator '
#                                                 'abundance which produces '
#                                                 "predator-poor space, prey's "
#                                                 'ability to assess spatial '
#                                                 'heterogeneity in risk, and '
#                                                 'few or weak constraints on '
#                                                 'the ability to settle in '
#                                                 'within predator-poor space. '
#                                                 'We used a 15-year dataset on '
#                                                 'forested grids that provided '
#                                                 'extensive records of fledging '
#                                                 'success of veeries (Catharus '
#                                                 'fuscescens) and ovenbirds '
#                                                 '(Seiurus aurocapilla) in '
#                                                 'relation to areas of low and '
#                                                 'high spatial clustering of an '
#                                                 'important nest predator, the '
#                                                 'eastern chipmunk (Tamias '
#                                                 'striatus).   Ovenbird nests '
#                                                 'were built in locations with '
#                                                 'significantly lower chipmunk '
#                                                 'clustering at a scale of '
#                                                 '900m2, relative to random '
#                                                 'locations within our study '
#                                                 'grids.  In contrast, veery '
#                                                 'nests were built at sites '
#                                                 'with significantly higher '
#                                                 'chipmunk clustering relative '
#                                                 'to random locations. Veery '
#                                                 'nest site preference for '
#                                                 'dense shrub patches may '
#                                                 'increase their vulnerability '
#                                                 'to chipmunks seeking shrubs '
#                                                 'to reduce their own '
#                                                 'vulnerability to predators.  '
#                                                 'Despite interspecific '
#                                                 'differences in nest placement '
#                                                 'and avoidance of chipmunk '
#                                                 'clusters, for both species '
#                                                 'fledging success was '
#                                                 'unaffected by surrounding '
#                                                 'chipmunk activity. This study '
#                                                 'highlights key differences in '
#                                                 'the use of predator-poor '
#                                                 'space among coexisting '
#                                                 'species, and highlights the '
#                                                 'need to consider constraints '
#                                                 'due to other habitat '
#                                                 'preferences and large '
#                                                 'predator communities.',
#                                  'doi': '10.5061/dryad.pn371m9',
#                                  'keywords': ['spatial-heterogeneity in '
#                                               'predation risk',
#                                               'SADIE',
#                                               'nest predation',
#                                               'Tamias striatus',
#                                               'Breeding habitat selection',
#                                               'spatial analysis by distance '
#                                               'indices',
#                                               'Seiurus aurocapilla',
#                                               'Catharus fuscescens'],
#                                  'license': {'id': 'CC0-1.0'},
#                                  'locations': [{'place': 'Northeast USA'}],
#                                  'notes': '<div '
#                                           'class="o-metadata__file-usage-entry">Data_Schmdit '
#                                           'et al. JAB01946<div '
#                                           'class="o-metadata__file-description">Summary '
#                                           'data for chipmunk annual '
#                                           'aggregation, local cluster indices, '
#                                           'and cluster indices at the 9-trap '
#                                           'neighborhoods surrounding veery and '
#                                           'ovenbird nests</div><div '
#                                           'class="o-metadata__file-name">Data_Emmering '
#                                           'et al. '
#                                           'JAB01946.xlsx<br></div></div><p>Funding '
#                                           'provided by: National Science '
#                                           'Foundation<br>Award Number: DEB '
#                                           '0075277, DEB 0444585, DEB 0949702, '
#                                           'DEB 1456527, DEB 0089588, DEB '
#                                           '0746985</p>',
#                                  'publication_date': '2018-11-06',
#                                  'related_identifiers': [{'identifier': '10.1111/jav.01946',
#                                                           'relation': 'cites',
#                                                           'scheme': 'doi'}],
#                                  'relations': {'version': [{'count': 1,
#                                                             'index': 0,
#                                                             'is_last': True,
#                                                             'last_child': {'pid_type': 'recid',
#                                                                            'pid_value': '4936921'},
#                                                             'parent': {'pid_type': 'recid',
#                                                                        'pid_value': '4936920'}}]},
#                                  'resource_type': {'title': 'Dataset',
#                                                    'type': 'dataset'},
#                                  'title': 'Data from: Variation in coexisting '
#                                           'birds to exploit spatial '
#                                           'heterogeneity in small mammal '
#                                           'activity'},
#                     'owners': [90070],
#                     'revision': 2,
#                     'stats': {'downloads': 0.0,
#                               'unique_downloads': 0.0,
#                               'unique_views': 0.0,
#                               'version_downloads': 0.0,
#                               'version_unique_downloads': 0.0,
#                               'version_unique_views': 0.0,
#                               'version_views': 0.0,
#                               'version_volume': 0.0,
#                               'views': 0.0,
#                               'volume': 0.0},
#                     'updated': '2021-06-13T01:48:30.019799+00:00'},
#                    {'conceptdoi': '10.5281/zenodo.2591545',
#                     'conceptrecid': '2591545',
#                     'created': '2019-03-12T18:46:50.072723+00:00',
#                     'doi': '10.5281/zenodo.2591546',
#                     'files': [{'bucket': 'cce5e8b9-01c7-4afd-8cc7-2ac6d508fb04',
#                                'checksum': 'md5:76c91667e1f2732b6e01dd1cf4079948',
#                                'key': 'tplinderoth/ABCutils-v1.0.0.zip',
#                                'links': {'self': 'https://zenodo.org/api/files/cce5e8b9-01c7-4afd-8cc7-2ac6d508fb04/tplinderoth/ABCutils-v1.0.0.zip'},
#                                'size': 63094,
#                                'type': 'zip'}],
#                     'id': 2591546,
#                     'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.2591546.svg',
#                               'bucket': 'https://zenodo.org/api/files/cce5e8b9-01c7-4afd-8cc7-2ac6d508fb04',
#                               'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.2591545.svg',
#                               'conceptdoi': 'https://doi.org/10.5281/zenodo.2591545',
#                               'doi': 'https://doi.org/10.5281/zenodo.2591546',
#                               'html': 'https://zenodo.org/record/2591546',
#                               'latest': 'https://zenodo.org/api/records/2591546',
#                               'latest_html': 'https://zenodo.org/record/2591546',
#                               'self': 'https://zenodo.org/api/records/2591546'},
#                     'metadata': {'access_right': 'open',
#                                  'access_right_category': 'success',
#                                  'creators': [{'affiliation': 'University of '
#                                                               'Cambridge',
#                                                'name': 'tplinderoth'}],
#                                  'description': '<p>Scripts used in the '
#                                                 'chipmunk study by Bi et al. '
#                                                 '(2019) under the working '
#                                                 "title 'Temporal genomic "
#                                                 'contrasts reveal rapid '
#                                                 'evolutionary responses in an '
#                                                 'alpine mammal during recent '
#                                                 "climate change'.</p>",
#                                  'doi': '10.5281/zenodo.2591546',
#                                  'license': {'id': 'other-open'},
#                                  'publication_date': '2019-03-12',
#                                  'related_identifiers': [{'identifier': 'https://github.com/tplinderoth/ABCutils/tree/v1.0.0',
#                                                           'relation': 'isSupplementTo',
#                                                           'scheme': 'url'},
#                                                          {'identifier': '10.5281/zenodo.2591545',
#                                                           'relation': 'isVersionOf',
#                                                           'scheme': 'doi'}],
#                                  'relations': {'version': [{'count': 1,
#                                                             'index': 0,
#                                                             'is_last': True,
#                                                             'last_child': {'pid_type': 'recid',
#                                                                            'pid_value': '2591546'},
#                                                             'parent': {'pid_type': 'recid',
#                                                                        'pid_value': '2591545'}}]},
#                                  'resource_type': {'title': 'Software',
#                                                    'type': 'software'},
#                                  'title': 'tplinderoth/ABCutils: ABCutils '
#                                           'first release',
#                                  'version': 'v1.0.0'},
#                     'owners': [62710],
#                     'revision': 6,
#                     'stats': {'downloads': 5.0,
#                               'unique_downloads': 4.0,
#                               'unique_views': 34.0,
#                               'version_downloads': 5.0,
#                               'version_unique_downloads': 4.0,
#                               'version_unique_views': 34.0,
#                               'version_views': 39.0,
#                               'version_volume': 315470.0,
#                               'views': 39.0,
#                               'volume': 315470.0},
#                     'updated': '2020-01-24T19:26:49.238472+00:00'},
#                    {'conceptrecid': '4990061',
#                     'created': '2021-06-19T03:43:48.528726+00:00',
#                     'doi': '10.5061/dryad.3583j',
#                     'files': [{'bucket': '62c232fc-b45a-4bed-b527-2054e9d657df',
#                                'checksum': 'md5:f411331fe9f1d5a71c40a5de51a00262',
#                                'key': 'covariance_matrices_neotamias.xls',
#                                'links': {'self': 'https://zenodo.org/api/files/62c232fc-b45a-4bed-b527-2054e9d657df/covariance_matrices_neotamias.xls'},
#                                'size': 608256,
#                                'type': 'xls'},
#                               {'bucket': '62c232fc-b45a-4bed-b527-2054e9d657df',
#                                'checksum': 'md5:b513acb10aeb8f85e4a5c00238e6d737',
#                                'key': 'README_for_covariance_matrices_neotamias.docx',
#                                'links': {'self': 'https://zenodo.org/api/files/62c232fc-b45a-4bed-b527-2054e9d657df/README_for_covariance_matrices_neotamias.docx'},
#                                'size': 146703,
#                                'type': 'docx'}],
#                     'id': 4990062,
#                     'links': {'badge': 'https://zenodo.org/badge/doi/10.5061/dryad.3583j.svg',
#                               'bucket': 'https://zenodo.org/api/files/62c232fc-b45a-4bed-b527-2054e9d657df',
#                               'doi': 'https://doi.org/10.5061/dryad.3583j',
#                               'html': 'https://zenodo.org/record/4990062',
#                               'latest': 'https://zenodo.org/api/records/4990062',
#                               'latest_html': 'https://zenodo.org/record/4990062',
#                               'self': 'https://zenodo.org/api/records/4990062'},
#                     'metadata': {'access_right': 'open',
#                                  'access_right_category': 'success',
#                                  'communities': [{'id': 'dryad'}],
#                                  'creators': [{'affiliation': 'University of '
#                                                               'Sao Paulo',
#                                                'name': 'Assis, Ana Paula '
#                                                        'Aprígio'},
#                                               {'affiliation': 'University of '
#                                                               'Sao Paulo',
#                                                'name': 'Rossoni, Daniela '
#                                                        'Munhoz'},
#                                               {'affiliation': 'University of '
#                                                               'Sao Paulo',
#                                                'name': 'Patton, James L.'},
#                                               {'affiliation': 'University of '
#                                                               'Sao Paulo',
#                                                'name': 'Marroig, Gabriel'}],
#                                  'description': 'The importance of the '
#                                                 'environment in shaping '
#                                                 'phenotypic evolution lies at '
#                                                 'the core of evolutionary '
#                                                 'biology. Chipmunks of the '
#                                                 'genus Tamias (subgenus '
#                                                 'Neotamias) are part of a very '
#                                                 'recent radiation, occupying a '
#                                                 'wide range of environments '
#                                                 'with marked niche '
#                                                 'partitioning among species. '
#                                                 'One open question is if and '
#                                                 'how those differences in '
#                                                 'environments affected '
#                                                 'phenotypic evolution in this '
#                                                 'lineage. Herein we examine '
#                                                 'the relative importance of '
#                                                 'genetic drift versus natural '
# ...
#                                           'alpinus glucocorticoid data and '
#                                           'associated biological and '
#                                           'environmental data collected '
#                                           '2013-2015 in Yosemite National Park '
#                                           'and surrounding areas.</div><div '
#                                           'class="o-metadata__file-name"></div></div>',
#                                  'publication_date': '2018-06-26',
#                                  'related_identifiers': [{'identifier': '10.1002/eap.1781',
#                                                           'relation': 'cites',
#                                                           'scheme': 'doi'}],
#                                  'relations': {'version': [{'count': 1,
#                                                             'index': 0,
#                                                             'is_last': True,
#                                                             'last_child': {'pid_type': 'recid',
#                                                                            'pid_value': '4945753'},
#                                                             'parent': {'pid_type': 'recid',
#                                                                        'pid_value': '4945752'}}]},
#                                  'resource_type': {'title': 'Dataset',
#                                                    'type': 'dataset'},
#                                  'title': 'Data from: '
#                                           'Glucocorticoid-environment '
#                                           'relationships align with responses '
#                                           'to environmental change in two '
#                                           'co-occurring congeners'},
#                     'owners': [90070],
#                     'revision': 2,
#                     'stats': {'downloads': 0.0,
#                               'unique_downloads': 0.0,
#                               'unique_views': 0.0,
#                               'version_downloads': 0.0,
#                               'version_unique_downloads': 0.0,
#                               'version_unique_views': 0.0,
#                               'version_views': 0.0,
#                               'version_volume': 0.0,
#                               'views': 0.0,
#                               'volume': 0.0},
#                     'updated': '2021-06-14T13:48:20.684520+00:00'},
#                    {'conceptrecid': '5009452',
#                     'created': '2021-06-22T01:29:49.219869+00:00',
#                     'doi': '10.5061/dryad.708b0',
#                     'files': [{'bucket': 'b714dfba-8ce3-43a5-918e-369414cfa535',
#                                'checksum': 'md5:5223cb1ca6a35d88063d70ad2638f8de',
#                                'key': 'Data_Fiola et al..xlsx',
#                                'links': {'self': 'https://zenodo.org/api/files/b714dfba-8ce3-43a5-918e-369414cfa535/Data_Fiola%20et%20al..xlsx'},
#                                'size': 41717,
#                                'type': 'xlsx'}],
#                     'id': 5009453,
#                     'links': {'badge': 'https://zenodo.org/badge/doi/10.5061/dryad.708b0.svg',
#                               'bucket': 'https://zenodo.org/api/files/b714dfba-8ce3-43a5-918e-369414cfa535',
#                               'doi': 'https://doi.org/10.5061/dryad.708b0',
#                               'html': 'https://zenodo.org/record/5009453',
#                               'latest': 'https://zenodo.org/api/records/5009453',
#                               'latest_html': 'https://zenodo.org/record/5009453',
#                               'self': 'https://zenodo.org/api/records/5009453'},
#                     'metadata': {'access_right': 'open',
#                                  'access_right_category': 'success',
#                                  'communities': [{'id': 'dryad'}],
#                                  'creators': [{'affiliation': 'Université de '
#                                                               'Moncton',
#                                                'name': 'Fiola, Marie-Line'},
#                                               {'affiliation': 'University of '
#                                                               'Manitoba',
#                                                'name': 'Vernouillet, Alizée'},
#                                               {'affiliation': 'Université du '
#                                                               'Québec à '
#                                                               'Rimouski',
#                                                'name': 'Villard, Marc-André'}],
#                                  'description': 'The ecological literature '
#                                                 'presents considerable '
#                                                 'evidence for top-down forcing '
#                                                 'on the maintenance of species '
#                                                 'diversity. Yet, in temperate '
#                                                 'forests, bottom-up forces '
#                                                 'often exert a strong '
#                                                 'influence on ecosystem '
#                                                 'functioning. Here, we report '
#                                                 'on the indirect influence of '
#                                                 'a pulsed resource, sugar '
#                                                 'maple (Acer saccharum) seed '
#                                                 'production, on nest survival '
#                                                 'in a migratory songbird. We '
#                                                 'hypothesized that seed '
#                                                 'production in year t would '
#                                                 'determine daily nest survival '
#                                                 'rate in year t + 1 through '
#                                                 'its effects on seed-eating '
#                                                 'rodents. We used the density '
#                                                 'of sugar maple seedlings '
#                                                 '(with cotyledons) in year t + '
#                                                 '1 as a proxy for seed '
#                                                 'production in year t and '
#                                                 'predicted that it would be '
#                                                 'inversely related to songbird '
#                                                 'nest survival the same year. '
#                                                 'We estimated the density of '
#                                                 'sugar maple seedlings, '
#                                                 'eastern chipmunk (Tamias '
#                                                 'striatus) activity, and daily '
#                                                 'nest survival rate in the '
#                                                 'ovenbird (Seiurus '
#                                                 'aurocapilla) over four '
#                                                 'successive years in a '
#                                                 'northern hardwood forest of '
#                                                 'New Brunswick, Canada. '
#                                                 'Seedling density varied by '
#                                                 'two orders of magnitude '
#                                                 'between years, whereas an '
#                                                 'index of chipmunk activity '
#                                                 'changed by an order of '
#                                                 'magnitude. Both variables '
#                                                 'were positively correlated '
#                                                 'and negatively correlated to '
#                                                 'daily nest survival rate. A '
#                                                 'logistic-exposure model '
#                                                 'including only seedling '
#                                                 'density received the greatest '
#                                                 'level of support (lowest '
#                                                 'AICc). Previous studies have '
#                                                 'reported the effect of sugar '
#                                                 'maple masting on seed-eating '
#                                                 'rodent populations, but the '
#                                                 'strong link we report between '
#                                                 'seedling density and songbird '
#                                                 'nest survival is novel. A '
#                                                 'nocturnal seed-eating nest '
#                                                 'predator, deer mouse '
#                                                 '(Peromyscus maniculatus), was '
#                                                 'not considered in our models, '
#                                                 'which may explain why '
#                                                 'chipmunk was not the best '
#                                                 'predictor of daily nest '
#                                                 'survival rate. The trophic '
#                                                 'linkages we observed are '
#                                                 'remarkably strong for a '
#                                                 'temperate forest ecosystem '
#                                                 'and might become more '
#                                                 'prevalent in northeastern '
#                                                 'North America, at least on '
#                                                 'calcium-rich soils, with the '
#                                                 'loss of large-diameter beech '
#                                                 'trees as a result of beech '
#                                                 'bark disease.',
#                                  'doi': '10.5061/dryad.708b0',
#                                  'keywords': ['nest predation',
#                                               'Tamias striatus',
#                                               'indirect effects',
#                                               'resource pulse',
#                                               'Acer saccharum',
#                                               'eastern deciduous forest',
#                                               'Peromyscus maniculatus',
#                                               '2012-2015',
#                                               'Migratory songbirds',
#                                               'Seiurus aurocapilla'],
#                                  'license': {'id': 'CC0-1.0'},
#                                  'locations': [{'place': 'New-Brunswick'}],
#                                  'notes': '<div '
#                                           'class="o-metadata__file-usage-entry">Data '
#                                           'from: Linking songbird nest '
#                                           'predation to seedling density: '
#                                           'sugar maple masting as a resource '
#                                           'pulse in a forest food web<div '
#                                           'class="o-metadata__file-description">Nest '
#                                           'data were collected in four 25 ha '
#                                           'plots from 2012 to 2015. Each line '
#                                           'corresponds to an Ovenbird nest. '
#                                           'The number of exposure days was '
#                                           'used to calculate the daily '
#                                           'survival rate of nests. Mean '
#                                           'chipmunk detections corresponds to '
#                                           'the mean number of visual or aural '
#                                           'detections recorded in each plot '
#                                           'and year (6 surveys per plot per '
#                                           'year). Mean seedling density '
#                                           'indicates the mean density of '
#                                           'newly-emerged sugar maple seedlings '
#                                           '(with cotyledons) counted in fifty '
#                                           '250 cm^2 quadrats in each plot and '
#                                           'year. Treatment refers to selection '
#                                           'harvesting (30-40% basal area '
#                                           'removal) conducted in two of the '
#                                           'four plots during the winter of '
#                                           '2006-2007.</div><div '
#                                           'class="o-metadata__file-name">Data_Fiola '
#                                           'et al..xlsx<br></div></div>',
#                                  'publication_date': '2018-10-17',
#                                  'related_identifiers': [{'identifier': '10.1002/ece3.3581',
#                                                           'relation': 'cites',
#                                                           'scheme': 'doi'}],
#                                  'relations': {'version': [{'count': 1,
#                                                             'index': 0,
#                                                             'is_last': True,
#                                                             'last_child': {'pid_type': 'recid',
#                                                                            'pid_value': '5009453'},
#                                                             'parent': {'pid_type': 'recid',
#                                                                        'pid_value': '5009452'}}]},
#                                  'resource_type': {'title': 'Dataset',
#                                                    'type': 'dataset'},
#                                  'title': 'Data from: Linking songbird nest '
#                                           'predation to seedling density: '
#                                           'sugar maple masting as a resource '
#                                           'pulse in a forest food web'},
#                     'owners': [90070],
#                     'revision': 2,
#                     'stats': {'downloads': 0.0,
#                               'unique_downloads': 0.0,
#                               'unique_views': 0.0,
#                               'version_downloads': 0.0,
#                               'version_unique_downloads': 0.0,
#                               'version_unique_views': 0.0,
#                               'version_views': 0.0,
#                               'version_volume': 0.0,
#                               'views': 0.0,
#                               'volume': 0.0},
#                     'updated': '2021-06-23T01:48:23.883280+00:00'}],
#           'total': 31},
#  'links': {'next': 'https://zenodo.org/api/records/?sort=bestmatch&q=chipmunk&page=2&size=10',
#            'self': 'https://zenodo.org/api/records/?sort=bestmatch&q=chipmunk&page=1&size=10'}}

# %%
#Convert output to pd dataframe and see table format
output_df = pd.json_normalize(output)

output_df

# %%
## Extract 'hits.hits' column and convert to dataframe
# note that name of column needs to be as string
hits_df = unnest_column(output_df, 'hits.hits')

# %%
output_df['hits.hits']

# %%
hits_df.head()

# %%
## Determine which columns are themselves lists or dictionaries and need to be unnested
cols_nested = columns_to_expand(hits_df)

# %%
cols_nested

# %%
## For each list or dict column, expand column, rename columns to clarify source, and merge
unnested_output_ = expand_columns(hits_df, cols_nested)

# %%
unnested_output.head()

# %%
unnested_output[['files_0', 'files_1', 'files_2', 'files_3']]

# %%
test_dict = {'a': [test_dict, test_dict], 'b': [4,5,6]}
df = pd.DataFrame(test_dict)

# %%
df
